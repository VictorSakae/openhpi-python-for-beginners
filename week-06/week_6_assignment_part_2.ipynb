# %% [markdown]
# Python1 Week 6: Assignment
# ======================
# # Accessing the Apple iTunes Search Service
#
# In this assignment you are going to build a Python program to access the
# [Apple iTunes Search Service](https://developer.apple.com/library/archive/documentation/AudioVideo/Conceptual/iTuneSearchAPI/Searching.html).
# This service can be used to search information about musicians, albums, songs and so on.
#
# Using the following URL, a search for the term _ramones_ and for the entity type
# _album_ is performed:
# [https://itunes.apple.com/search?term=ramones&entity=album](https://itunes.apple.com/search?term=ramones&entity=album)
#
# Other possible entity types are musicArtist, musicTrack or song. Below is an (abbreviated)
# example result of the service:
#
#     {
#     "resultCount": 1,
#     "results": [
#         {
#         "wrapperType": "collection",
#         "collectionType": "Album",
#         "artistId": 60715,
#         "amgArtistId": 5223,
#         "artistName": "Ramones",
#         "collectionName": "Ramones",
#         "collectionPrice": 9.99,
#         "collectionExplicitness": "notExplicit",
#         "trackCount": 14,
#         "copyright": "℗ 1976 Sire Records. Marketed by Rhino Entertainment Company, a Warner Music Group Company.",
#         "country": "USA",
#         "currency": "USD",
#         "releaseDate": "1976-04-23T08:00:00Z",
#         "primaryGenreName": "Punk"
#         }
#     ]
#     }
#
# The response in the example above consists of one result (`resultCount` is 1). This result is the album
# "Ramones" (element `collectionName`) by the artist "Ramones" (element `artistName`).
# The response is in [JSON](https://en.wikipedia.org/wiki/JSON) format.
#
# The [Requests](https://docs.python-requests.org/en/latest/)
# library can be used to invoke the Apple iTunes Search Service.
# In order to perform a search, a [GET request](https://en.wikipedia.org/wiki/Hypertext_Transfer_Protocol#Request_methods)
# needs to be performed. This is done using the `get()` function of the Requests library.
# After that, the method `json()` of the Requests
# library can be used to map the response from [JSON](https://en.wikipedia.org/wiki/JSON)
# to the Python 🐍 data types `dict` and `list`.
#
# ---
#
# # Assignment
#
# Write a program that asks the user for a search term. Perform a search using the iTunes search service
# for the entity type album. The program should then print how many search results where returned.
# For each result print the artist name, the album name and track count.
#
# Below is an example execution of the program. Note that the output is abbreviated.
#
#     Please enter a search term: cash
#     The search returned 50 results.
#     Artist: Luke Bryan - Album: Crash My Party - Track Count: 13
#     Artist: Johnny Cash - Album: The Essential Johnny Cash - Track Count: 36
#     Artist: Dave Matthews Band - Album: Crash - Track Count: 12
#
# # Hints
#
# 1. In Code Ocean it is not possible to access the iTunes search API. Therefore you should
#    write and test your program on your own computer e.g. in a Jupyter notebook.
# 1. Our tests in Code Ocean use a [mock object](https://en.wikipedia.org/wiki/Mock_object) to check
#    your program. Therefore only the `get()` function and the `json()` method are supported. All other
#    functions and methods of the Requests library will **not** work.

# %%
import requests 

search = input("Please enter a search term:")
payload = {'term': search, 'entity': 'album'}

r = requests.get('https://itunes.apple.com/search', params=payload)

response = r.json()
result_count = response.get('resultCount') 
print(f"The search returned {result_count} results.")

results = response.get('results')

for item in results:
    artist = item.get('artistName')
    album = item.get('collectionName')
    track_count = item.get('trackCount')
    print(f"Artist: {artist} - Album: {album} - Track Count: {track_count}")
# Out:
# Please enter a search term: ramones
# The search returned 50 results.
# Artist: Ramones - Album: Ramones - Track Count: 14
# Artist: Ramones - Album: Hey Ho Let's Go: Greatest Hits - Track Count: 20
# Artist: Ramones - Album: Rocket to Russia - Track Count: 14
# Artist: Ramones - Album: Road to Ruin - Track Count: 12
# Artist: Ramones - Album: Ramones Mania - Track Count: 30
# Artist: Ramones - Album: End of the Century (Deluxe Edition) - Track Count: 19
# Artist: Ramones - Album: Leave Home (40th Anniversary Deluxe Edition) - Track Count: 80
# Artist: Ramones - Album: Brain Drain - Track Count: 12
# Artist: Ramones - Album: Pleasant Dreams (Deluxe Edition) - Track Count: 19
# Artist: Ramones - Album: It's Alive (Live) - Track Count: 28
# Artist: Ramones - Album: Road to Ruin (Deluxe Edition) - Track Count: 17
# Artist: Ramones - Album: Animal Boy - Track Count: 12
# Artist: Ramones - Album: Rocket to Russia (Deluxe Edition) - Track Count: 19
# Artist: Ramones - Album: Adios Amigos - Track Count: 13
# Artist: Ramones - Album: It's Alive (Live) [40th Anniversary Deluxe Edition] - Track Count: 109
# Artist: Ramones - Album: Mondo Bizarro - Track Count: 13
# Artist: Ramones - Album: Halfway to Sanity - Track Count: 12
# Artist: Ramones - Album: Acid Eaters - Track Count: 12
# Artist: Ramones - Album: Too Tough to Die (Deluxe Edition) - Track Count: 25
# Artist: Ramones - Album: Spider-Man - Single - Track Count: 2
# Artist: Ramones - Album: Subterranean Jungle (Deluxe Edition) - Track Count: 19
# Artist: Ramones - Album: Rocket to Russia (40th Anniversary Deluxe Edition) - Track Count: 77
# Artist: Ramones - Album: End of the Century - Track Count: 12
# Artist: Ramones - Album: Ramones (Deluxe Edition) - Track Count: 22
# Artist: Ramones - Album: Loco Live - Track Count: 32
# Artist: Ramones - Album: Greatest Hits Live (River Plate Stadium, Buenos Aires 3/16/96) - Track Count: 18
# Artist: Ramones - Album: The Sire Years 1976-1981 - Track Count: 78
# Artist: Ramones - Album: We're Outta Here! (Live) - Track Count: 32
# Artist: Ramones - Album: Too Tough to Die - Track Count: 13
# Artist: Ramones - Album: Pleasant Dreams - Track Count: 12
# Artist: Ramones - Album: Leave Home - Track Count: 14
# Artist: Ramones - Album: Road to Ruin (40th Anniversary Deluxe Edition) - Track Count: 80
# Artist: Ramones - Album: Hey Ho Let's Go - Single - Track Count: 2
# Artist: Los Ramones De Nuevo Leon - Album: Sigue la Tradición - Track Count: 12
# Artist: Ramones - Album: Subterranean Jungle - Track Count: 12
# Artist: Ramones - Album: Leave Home (Deluxe Edition) - Track Count: 31
# Artist: FLAWLESS PRODIGY - Album: RAMONES (feat. ilovedamar) - Single - Track Count: 1
# Artist: Rockabye Baby! - Album: Lullaby Renditions of the Ramones - Track Count: 12
# Artist: Ramones - Album: Judy Is a Punk (Lost 1975 Demo Versions) - Single - Track Count: 2
# Artist: Ramones - Album: Gabba Gabba Hey - Single - Track Count: 2
# Artist: Ramones - Album: I Wanna Be Your Boyfriend (1975 Demos) - Single - Track Count: 2
# Artist: Los Ramones De Nuevo Leon - Album: Quieres Ser Mi Novia - Single - Track Count: 1
# Artist: SHONEN KNIFE - Album: Osaka Ramones - Tribute to The Ramones - Track Count: 13
# Artist: Los Ramones De Nuevo Leon - Album: Así Nomás - Track Count: 12
# Artist: Los Ramones De Nuevo Leon - Album: Me Cambiaste La Vida - Single - Track Count: 1
# Artist: Los Ramones De Nuevo Leon - Album: Regias de Corazón - Track Count: 16
# Artist: Los Ramones De Nuevo Leon - Album: México Cantaba, Vol.1 - Track Count: 15
# Artist: Los Ramones De Nuevo Leon - Album: Con la Rienda Suelta - Track Count: 10
# Artist: Grupo H100 & Los Ramones De Nuevo Leon - Album: Con un Trago Chacaleño - Single - Track Count: 1
# Artist: Twinkle Twinkle Little Rock Star - Album: Lullaby Versions of Ramones - Track Count: 14
